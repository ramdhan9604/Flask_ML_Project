# %% [markdown]
# ## 1. Importing Libraries

# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.1.2-cp313-cp313-win_amd64.whl.metadata (59 kB)
# Using cached numpy-2.1.2-cp313-cp313-win_amd64.whl (12.6 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.5 MB 10.3 MB/s eta 0:00:01
#    ------------ --------------------------- 3.7/11.5 MB 9.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.0/11.5 MB 8.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.8/11.5 MB 8.3 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.5 MB 8.2 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.5 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 6.9 MB/s eta 0:00:00
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2024.2 tzdata-2024.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from scikit-learn) (2.1.2)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.2-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.0 MB 11.9 MB/s eta 0:00:01
#    -------------- ------------------------- 3.9/11.0 MB 9.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/11.0 MB 7.9 MB/s eta 0:00:01
#    --------------------- ------------------ 5.8/11.0 MB 6.9 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.0 MB 6.4 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.0 MB 6.3 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.0 MB 6.0 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 5.0 MB/s eta 0:00:00
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.5/44.5 MB 2.7 MB/s eta 0:00:17
#    - -------------------------------------- 1.6/44.5 MB 4.0 MB/s eta 0:00:11
#    - -------------------------------------- 2.1/44.5 MB 3.4 MB/s eta 0:00:13
#    --- ------------------------------------ 3.4/44.5 MB 4.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 4.7/44.5 MB 4.5 MB/s eta 0:00:09
#    ----- ---------------------------------- 6.0/44.5 MB 4.9 MB/s eta 0:00:08
#    ------ --------------------------------- 7.6/44.5 MB 5.1 MB/s eta 0:00:08
#    -------- ------------------------------- 8.9/44.5 MB 5.3 MB/s eta 0:00:07
#    --------- ------------------------------ 10.5/44.5 MB 5.6 MB/s eta 0:00:07
#    ---------- ----------------------------- 12.1/44.5 MB 5.8 MB/s eta 0:00:06
#    ------------ --------------------------- 13.6/44.5 MB 6.0 MB/s eta 0:00:06
#    ------------- -------------------------- 15.5/44.5 MB 6.2 MB/s eta 0:00:05
#    --------------- ------------------------ 17.0/44.5 MB 6.3 MB/s eta 0:00:05
#    ---------------- ----------------------- 18.9/44.5 MB 6.5 MB/s eta 0:00:04
#    ------------------ --------------------- 20.7/44.5 MB 6.6 MB/s eta 0:00:04
#    ------------------- -------------------- 22.0/44.5 MB 6.6 MB/s eta 0:00:04
#    --------------------- ------------------ 23.6/44.5 MB 6.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 25.4/44.5 MB 6.8 MB/s eta 0:00:03
#    ------------------------ --------------- 27.0/44.5 MB 6.9 MB/s eta 0:00:03
#    ------------------------- -------------- 28.6/44.5 MB 6.9 MB/s eta 0:00:03
#    -------------------------- ------------- 29.9/44.5 MB 6.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 31.5/44.5 MB 6.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.0/44.5 MB 6.9 MB/s eta 0:00:02
#    ------------------------------- -------- 34.6/44.5 MB 7.0 MB/s eta 0:00:02
#    -------------------------------- ------- 36.4/44.5 MB 7.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 38.0/44.5 MB 7.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.8/44.5 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------- -- 41.2/44.5 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 42.5/44.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 6.8 MB/s eta 0:00:00
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (1.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install feature_engine
# Out:
# Collecting feature_engineNote: you may need to restart the kernel to use updated packages.
#
#   Downloading feature_engine-1.8.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from feature_engine) (2.1.2)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from feature_engine) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from feature_engine) (1.5.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from feature_engine) (1.14.1)
# Collecting statsmodels>=0.11.1 (from feature_engine)
#   Downloading statsmodels-0.14.4-cp313-cp313-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python313\site-packages (from pandas>=2.2.0->feature_engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from pandas>=2.2.0->feature_engine) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from pandas>=2.2.0->feature_engine) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from scikit-learn>=1.4.0->feature_engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from scikit-learn>=1.4.0->feature_engine) (3.5.0)
# Collecting patsy>=0.5.6 (from statsmodels>=0.11.1->feature_engine)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\dell\appdata\roaming\python\python313\site-packages (from statsmodels>=0.11.1->feature_engine) (24.1)
# Requirement already satisfied: six in c:\users\dell\appdata\roaming\python\python313\site-packages (from patsy>=0.5.6->statsmodels>=0.11.1->feature_engine) (1.16.0)
# Downloading feature_engine-1.8.1-py2.py3-none-any.whl (364 kB)
# Downloading statsmodels-0.14.4-cp313-cp313-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.8 MB 10.0 MB/s eta 0:00:01
#    -------------- ------------------------- 3.7/9.8 MB 9.1 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.8 MB 8.5 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.8 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 7.9 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels, feature_engine
# Successfully installed feature_engine-1.8.1 patsy-0.5.6 statsmodels-0.14.4

# %%
pip install xgboost
# Out:
# Collecting xgboostNote: you may need to restart the kernel to use updated packages.
#
#   Downloading xgboost-2.1.1-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from xgboost) (2.1.2)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\envs\flask_env\lib\site-packages (from xgboost) (1.14.1)
# Downloading xgboost-2.1.1-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#     --------------------------------------- 1.8/124.9 MB 11.3 MB/s eta 0:00:11
#    - -------------------------------------- 3.7/124.9 MB 9.6 MB/s eta 0:00:13
#    - -------------------------------------- 5.2/124.9 MB 8.8 MB/s eta 0:00:14
#    -- ------------------------------------- 6.6/124.9 MB 8.2 MB/s eta 0:00:15
#    -- ------------------------------------- 8.1/124.9 MB 8.1 MB/s eta 0:00:15
#    --- ------------------------------------ 9.7/124.9 MB 8.0 MB/s eta 0:00:15
#    --- ------------------------------------ 11.3/124.9 MB 7.9 MB/s eta 0:00:15
#    ---- ----------------------------------- 12.8/124.9 MB 7.9 MB/s eta 0:00:15
#    ---- ----------------------------------- 14.7/124.9 MB 7.9 MB/s eta 0:00:14
#    ----- ---------------------------------- 16.3/124.9 MB 8.0 MB/s eta 0:00:14
#    ----- ---------------------------------- 17.8/124.9 MB 7.9 MB/s eta 0:00:14
#    ------ --------------------------------- 19.4/124.9 MB 7.9 MB/s eta 0:00:14
#    ------ --------------------------------- 20.7/124.9 MB 7.8 MB/s eta 0:00:14
#    ------- -------------------------------- 22.3/124.9 MB 7.7 MB/s eta 0:00:14
#    ------- -------------------------------- 23.6/124.9 MB 7.7 MB/s eta 0:00:14
#    -------- ------------------------------- 25.2/124.9 MB 7.6 MB/s eta 0:00:14
#    -------- ------------------------------- 26.7/124.9 MB 7.6 MB/s eta 0:00:13
#    -------- ------------------------------- 28.0/124.9 MB 7.6 MB/s eta 0:00:13
#    --------- ------------------------------ 29.6/124.9 MB 7.6 MB/s eta 0:00:13
#    --------- ------------------------------ 31.2/124.9 MB 7.6 MB/s eta 0:00:13
#    ---------- ----------------------------- 32.8/124.9 MB 7.6 MB/s eta 0:00:13
#    ----------- ---------------------------- 34.9/124.9 MB 7.7 MB/s eta 0:00:12
#    ----------- ---------------------------- 36.4/124.9 MB 7.7 MB/s eta 0:00:12
#    ------------ --------------------------- 37.7/124.9 MB 7.6 MB/s eta 0:00:12
#    ------------ --------------------------- 39.6/124.9 MB 7.7 MB/s eta 0:00:12
#    ------------- -------------------------- 41.2/124.9 MB 7.7 MB/s eta 0:00:11
#    ------------- -------------------------- 42.7/124.9 MB 7.7 MB/s eta 0:00:11
#    -------------- ------------------------- 44.0/124.9 MB 7.6 MB/s eta 0:00:11
#    -------------- ------------------------- 45.6/124.9 MB 7.6 MB/s eta 0:00:11
#    --------------- ------------------------ 47.2/124.9 MB 7.6 MB/s eta 0:00:11
#    --------------- ------------------------ 49.0/124.9 MB 7.6 MB/s eta 0:00:10
#    ---------------- ----------------------- 50.6/124.9 MB 7.6 MB/s eta 0:00:10
#    ---------------- ----------------------- 52.4/124.9 MB 7.7 MB/s eta 0:00:10
#    ----------------- ---------------------- 54.0/124.9 MB 7.7 MB/s eta 0:00:10
#    ----------------- ---------------------- 55.6/124.9 MB 7.7 MB/s eta 0:00:10
#    ------------------ --------------------- 56.9/124.9 MB 7.6 MB/s eta 0:00:09
#    ------------------ --------------------- 58.5/124.9 MB 7.6 MB/s eta 0:00:09
#    ------------------- -------------------- 59.8/124.9 MB 7.6 MB/s eta 0:00:09
#    ------------------- -------------------- 61.1/124.9 MB 7.6 MB/s eta 0:00:09
#    -------------------- ------------------- 62.7/124.9 MB 7.6 MB/s eta 0:00:09
#    -------------------- ------------------- 64.5/124.9 MB 7.6 MB/s eta 0:00:08
#    --------------------- ------------------ 66.1/124.9 MB 7.6 MB/s eta 0:00:08
#    --------------------- ------------------ 67.9/124.9 MB 7.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 69.5/124.9 MB 7.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 70.8/124.9 MB 7.6 MB/s eta 0:00:08
#    ----------------------- ---------------- 72.4/124.9 MB 7.6 MB/s eta 0:00:07
#    ----------------------- ---------------- 73.7/124.9 MB 7.5 MB/s eta 0:00:07
#    ------------------------ --------------- 75.5/124.9 MB 7.6 MB/s eta 0:00:07
#    ------------------------ --------------- 77.1/124.9 MB 7.6 MB/s eta 0:00:07
#    ------------------------- -------------- 78.9/124.9 MB 7.6 MB/s eta 0:00:07
#    ------------------------- -------------- 80.5/124.9 MB 7.6 MB/s eta 0:00:06
#    -------------------------- ------------- 82.6/124.9 MB 7.6 MB/s eta 0:00:06
#    -------------------------- ------------- 84.1/124.9 MB 7.6 MB/s eta 0:00:06
#    --------------------------- ------------ 85.2/124.9 MB 7.6 MB/s eta 0:00:06
#    --------------------------- ------------ 86.5/124.9 MB 7.6 MB/s eta 0:00:06
#    ---------------------------- ----------- 87.8/124.9 MB 7.5 MB/s eta 0:00:05
#    ---------------------------- ----------- 89.1/124.9 MB 7.5 MB/s eta 0:00:05
#    ---------------------------- ----------- 90.4/124.9 MB 7.5 MB/s eta 0:00:05
#    ----------------------------- ---------- 92.0/124.9 MB 7.5 MB/s eta 0:00:05
#    ----------------------------- ---------- 93.6/124.9 MB 7.5 MB/s eta 0:00:05
#    ------------------------------ --------- 95.2/124.9 MB 7.5 MB/s eta 0:00:04
#    ------------------------------- -------- 97.0/124.9 MB 7.5 MB/s eta 0:00:04
#    ------------------------------- -------- 98.6/124.9 MB 7.5 MB/s eta 0:00:04
#    -------------------------------- ------- 100.4/124.9 MB 7.5 MB/s eta 0:00:04
#    -------------------------------- ------- 102.0/124.9 MB 7.5 MB/s eta 0:00:04
#    --------------------------------- ------ 103.3/124.9 MB 7.5 MB/s eta 0:00:03
#    --------------------------------- ------ 104.9/124.9 MB 7.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 106.7/124.9 MB 7.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 108.3/124.9 MB 7.5 MB/s eta 0:00:03
#    ----------------------------------- ---- 110.1/124.9 MB 7.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 111.4/124.9 MB 7.5 MB/s eta 0:00:02
#    ------------------------------------ --- 112.7/124.9 MB 7.5 MB/s eta 0:00:02
#    ------------------------------------ --- 114.3/124.9 MB 7.5 MB/s eta 0:00:02
#    ------------------------------------- -- 115.6/124.9 MB 7.5 MB/s eta 0:00:02
#    ------------------------------------- -- 117.2/124.9 MB 7.5 MB/s eta 0:00:02
#    -------------------------------------- - 118.8/124.9 MB 7.5 MB/s eta 0:00:01
#    -------------------------------------- - 120.8/124.9 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  122.4/124.9 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.9 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  124.8/124.9 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 124.9/124.9 MB 7.4 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.1

# %%
import sklearn
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import learning_curve

from feature_engine.datetime import DatetimeFeatures

from xgboost import XGBRegressor

import joblib

import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Display Settings

# %%
pd.set_option("display.max_columns", None)

# %%
sklearn.set_config(transform_output="default")

# %% [markdown]
# ## 3. Getting the Data

# %%
train_df = pd.read_csv("data/train.csv")
val_df = pd.read_csv("data/val.csv")
test_df = pd.read_csv("data/test.csv")

# %%
train_df
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0          Jet Airways      2019-06-21    Mumbai   Hyderabad  10:20:00
# 1            Air India      2019-05-18     Delhi      Cochin  09:00:00
# 2            Air India      2019-06-12   Kolkata    Banglore  09:10:00
# 3              Vistara      2019-04-01   Kolkata    Banglore  20:20:00
# 4              Vistara      2019-06-06   Kolkata    Banglore  17:00:00
# ..                 ...             ...       ...         ...       ...
# 635           Air Asia      2019-04-12  Banglore       Delhi  04:55:00
# 636        Jet Airways      2019-05-09   Kolkata    Banglore  09:35:00
# 637             Indigo      2019-05-15  Banglore       Delhi  06:05:00
# 638  Multiple Carriers      2019-05-15     Delhi      Cochin  08:45:00
# 639        Jet Airways      2019-05-21   Kolkata    Banglore  20:00:00
#
#     arrival_time  duration  total_stops              additional_info  price
# 0       11:50:00        90          0.0  In-flight meal not included   4995
# 1       07:40:00      1360          1.0                      No Info   8372
# 2       11:05:00      1555          2.0                      No Info   6117
# 3       22:55:00      1595          1.0                      No Info   7770
# 4       10:45:00      1065          1.0                      No Info   9187
# ..           ...       ...          ...                          ...    ...
# 635     07:45:00       170          0.0                      No Info   4282
# 636     21:05:00       690          1.0                      No Info  13067
# 637     08:50:00       165          0.0                      No Info   4423
# 638     21:00:00       735          1.0                      No Info   7670
# 639     12:00:00       960          1.0  In-flight meal not included  10844
#
# [640 rows x 10 columns]

# %% [markdown]
# ### 3.1 Split the Data

# %%
def split_data(data):
	X = data.drop(columns="price")
	y = data.price.copy()
	return (X, y)

# %%
X_train, y_train = split_data(train_df)

# %%
X_train
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0          Jet Airways      2019-06-21    Mumbai   Hyderabad  10:20:00
# 1            Air India      2019-05-18     Delhi      Cochin  09:00:00
# 2            Air India      2019-06-12   Kolkata    Banglore  09:10:00
# 3              Vistara      2019-04-01   Kolkata    Banglore  20:20:00
# 4              Vistara      2019-06-06   Kolkata    Banglore  17:00:00
# ..                 ...             ...       ...         ...       ...
# 635           Air Asia      2019-04-12  Banglore       Delhi  04:55:00
# 636        Jet Airways      2019-05-09   Kolkata    Banglore  09:35:00
# 637             Indigo      2019-05-15  Banglore       Delhi  06:05:00
# 638  Multiple Carriers      2019-05-15     Delhi      Cochin  08:45:00
# 639        Jet Airways      2019-05-21   Kolkata    Banglore  20:00:00
#
#     arrival_time  duration  total_stops              additional_info
# 0       11:50:00        90          0.0  In-flight meal not included
# 1       07:40:00      1360          1.0                      No Info
# 2       11:05:00      1555          2.0                      No Info
# 3       22:55:00      1595          1.0                      No Info
# 4       10:45:00      1065          1.0                      No Info
# ..           ...       ...          ...                          ...
# 635     07:45:00       170          0.0                      No Info
# 636     21:05:00       690          1.0                      No Info
# 637     08:50:00       165          0.0                      No Info
# 638     21:00:00       735          1.0                      No Info
# 639     12:00:00       960          1.0  In-flight meal not included
#
# [640 rows x 9 columns]

# %%
y_train
# Out:
# 0       4995
# 1       8372
# 2       6117
# 3       7770
# 4       9187
#        ...
# 635     4282
# 636    13067
# 637     4423
# 638     7670
# 639    10844
# Name: price, Length: 640, dtype: int64

# %%
X_val, y_val = split_data(val_df)

print(X_val.shape, y_val.shape)
# Out:
# (160, 9) (160,)

# %%
X_test, y_test = split_data(test_df)

print(X_test.shape, y_test.shape)
# Out:
# (200, 9) (200,)

# %% [markdown]
# ### 3.2 Meta-info

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   airline          640 non-null    object
#  1   date_of_journey  640 non-null    object
#  2   source           640 non-null    object
#  3   destination      640 non-null    object
#  4   dep_time         640 non-null    object
#  5   arrival_time     640 non-null    object
#  6   duration         640 non-null    int64
#  7   total_stops      640 non-null    float64
#  8   additional_info  640 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 45.1+ KB

# %% [markdown]
# ## 4. Data Preprocessing

# %%
dt_cols = ["date_of_journey", "dep_time", "arrival_time"]

num_cols = ["duration", "total_stops"]

cat_cols = [col for col in X_train.columns if (col not in dt_cols) and (col not in num_cols)]

# %%
cat_cols
# Out:
# ['airline', 'source', 'destination', 'additional_info']

# %%
num_transformer = Pipeline(steps=[
	("imputer", SimpleImputer(strategy="median")),
	("scaler", StandardScaler())
])

cat_transformer = Pipeline(steps=[
	("imputer", SimpleImputer(strategy="most_frequent")),
	("encoder", OneHotEncoder(sparse_output=False, handle_unknown="ignore"))
])

doj_transformer = Pipeline(steps=[
	("imputer", SimpleImputer(strategy="most_frequent")),
	("extractor", DatetimeFeatures(features_to_extract=["month", "week", "day_of_week", "day_of_month"], format="mixed")),
	("scaler", StandardScaler())
])

time_transformer = Pipeline(steps=[
	("imputer", SimpleImputer(strategy="most_frequent")),
	("extractor", DatetimeFeatures(features_to_extract=["hour", "minute"], format="mixed")),
	("scaler", StandardScaler())
])

# %%
preprocessor = ColumnTransformer(transformers=[
	("num", num_transformer, num_cols),
	("cat", cat_transformer, cat_cols),
	("doj", doj_transformer, ["date_of_journey"]),
	("time", time_transformer, ["dep_time", "arrival_time"])
])

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[-1.09591823, -1.21213152,  0.        , ..., -0.14005709,
#         -0.34523131,  1.49385907],
#        [ 1.43569944,  0.31797533,  0.        , ..., -1.22986299,
#         -0.93560684,  0.89104078],
#        [ 1.82441239,  1.84808218,  0.        , ..., -0.68496004,
#         -0.34523131, -1.21882323],
#        ...,
#        [-0.94641325, -1.21213152,  0.        , ..., -0.95741152,
#         -0.78801296,  1.49385907],
#        [ 0.18982461,  0.31797533,  0.        , ...,  1.22220029,
#          1.1307075 , -1.52023237],
#        [ 0.63833955,  0.31797533,  0.        , ..., -1.22986299,
#         -0.19763743, -1.52023237]])

# %%
preprocessor.fit_transform(X_train).shape
# Out:
# (640, 33)

# %% [markdown]
# ## 5. Model Selection

# %%
algorithms = {
	"Linear Regression": LinearRegression(),
	"Support Vector Machine": SVR(),
	"Random Forest": RandomForestRegressor(n_estimators=10),
	"XG Boost": XGBRegressor(n_estimators=10)
}

# %%
data = pd.concat([train_df, val_df], axis=0)

X_data, y_data = split_data(data)
print(X_data.shape, y_data.shape)
# Out:
# (800, 9) (800,)

# %%
def plot_curves(sizes, mean_scores, std_scores, label, ax):
	ax.plot(
		sizes,
		mean_scores,
		marker="o",
		label=label
	)

	ax.fill_between(
		x=sizes,
		y1=mean_scores - std_scores,
		y2=mean_scores + std_scores,
		alpha=0.5
	)

# %%
def plot_learning_curves(name, algorithm, figsize=(12, 4)):
	model = Pipeline(steps=[
		("pre", preprocessor),
		("alg", algorithm)
	])

	train_sizes, train_scores, test_scores = learning_curve(
		estimator=model,
		X=X_data,
		y=y_data,
		cv=3,
		scoring="r2",
		n_jobs=-1,
		random_state=42
	)
	
	mean_train_scores = np.mean(train_scores, axis=1)
	std_train_scores = np.std(train_scores, axis=1)
	train_score = f"{mean_train_scores[-1]:.2f} +/- {std_train_scores[-1]:.2f}"

	mean_test_scores = np.mean(test_scores, axis=1)
	std_test_scores = np.std(test_scores, axis=1)
	test_score = f"{mean_test_scores[-1]:.2f} +/- {std_test_scores[-1]:.2f}"

	fig, ax = plt.subplots(figsize=figsize)

	# training curve
	plot_curves(
		train_sizes,
		mean_train_scores,
		std_train_scores,
		f"Train ({train_score})",
		ax
	)

	# test curve
	plot_curves(
		train_sizes,
		mean_test_scores,
		std_test_scores,
		f"Test ({test_score})",
		ax
	)

	ax.set(xlabel="Training Set Size", ylabel="R-square", title=name)

	ax.legend(loc="lower right")

	plt.show()

# %%
for name, alg in algorithms.items():
	plot_learning_curves(name, alg)

# %% [markdown]
# ## 6. Model Training

# %%
model = Pipeline(steps=[
	("pre", preprocessor),
	("rf", RandomForestRegressor(n_estimators=10))
])

# %%
model.fit(X_data, y_data)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['duration', 'total_stops']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['airline', 'source',
#                                                    '...
#                                                                                                          'day_of_month'],
#                                                                                     format='mixed')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['date_of_journey']),
#                                                  ('time',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('extractor',
#                                                                    DatetimeFeatures(features_to_extract=['hour',
#                                                                                                          'minute'],
#                                                                                     format='mixed')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['dep_time',
#                                                    'arrival_time'])])),
#                 ('rf', RandomForestRegressor(n_estimators=10))])

# %% [markdown]
# ## 7. Model Evaluation

# %%
def evaluate_model(X, y):
	y_pred = model.predict(X)
	return r2_score(y, y_pred)

# %%
print(f"R2 score on Training data is = {evaluate_model(X_data, y_data)}")
# Out:
# R2 score on Training data is = 0.951922813241827

# %%
print(f"R2 score on Test data is = {evaluate_model(X_test, y_test)}")
# Out:
# R2 score on Test data is = 0.6660203998759311

# %% [markdown]
# ## 8. Model Persistence

# %%
joblib.dump(model, "model.joblib")
# Out:
# ['model.joblib']

# %%
saved_model = joblib.load("model.joblib")
saved_model
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['duration', 'total_stops']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['airline', 'source',
#                                                    '...
#                                                                                                          'day_of_month'],
#                                                                                     format='mixed')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['date_of_journey']),
#                                                  ('time',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('extractor',
#                                                                    DatetimeFeatures(features_to_extract=['hour',
#                                                                                                          'minute'],
#                                                                                     format='mixed')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['dep_time',
#                                                    'arrival_time'])])),
#                 ('rf', RandomForestRegressor(n_estimators=10))])

# %%
y_pred = saved_model.predict(X_test)

r2_score(y_test, y_pred)
# Out:
# 0.6660203998759311
